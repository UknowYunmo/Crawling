# %%
# !pip install selenium

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import urllib.request
import time
#f=open('c:\\data\\gimo.txt','w',encoding='UTF-16')
binary = 'C:/Users/NICE/Downloads/chromedriver_win32/chromedriver.exe'
browser = webdriver.Chrome(binary)
browser.get("http://data.medigate.net/location")
browser.maximize_window()
time.sleep(2)
browser.implicitly_wait(2)
html = browser.page_source
soup = BeautifulSoup(html, "lxml")
browser.find_element_by_class_name('jss5').click()
browser.find_element_by_class_name('MuiButton-label').click()
time.sleep(2)
browser.implicitly_wait(2)
browser.find_element_by_xpath('//*[@id="root"]/div[2]/div[1]/div/div/div[1]/div[2]/div').click()
browser.find_element_by_xpath('//*[@id="popperSpecialty"]/div/div[3]/div[1]/div').click()
browser.find_element_by_xpath('//*[@id="popperSpecialty"]/div/div[1]/div[2]/button/span[1]').click()
browser.find_element_by_xpath('//*[@id="map"]/button').click()
time.sleep(2)
browser.implicitly_wait(2)
browser.find_element_by_xpath('/html/body/div[2]/div[3]/div/div/div[1]/div[3]/button').click()
time.sleep(2)
browser.implicitly_wait(2)
html = browser.page_source
soup = BeautifulSoup(html, "lxml")
soup.find_all('div', class_ ='aria-label')
soup
# Out:
# <html class="chrome mdl-js s4 pc" lang="en" style="overflow: hidden;"><head><script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-KJQ3WG7&amp;gtm_auth=&amp;gtm_preview=&amp;gtm_cookies_win=x"></script><script>
#       (function(w,d,s,l,i){w[l]=w[l]||[];
#         w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js', });
#         var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';
#         j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl+'&gtm_auth=&gtm_preview=&gtm_cookies_win=x';
#         f.parentNode.insertBefore(j,f);
# ...

# %%
# 손으로 지역 갱신한 뒤 클릭 ㅋㅋ

# %%
# 차트 업데이트
html = browser.page_source
soup = BeautifulSoup(html, "lxml")

# %%
for i in soup.select('g>g>g>g>g'):
    print(i.text)
# Out:
# 00
# 00
# 00
# 00
# 00
# 00
# 00
# 00
# 00
# 00
# 657657
# 481481
# 27,36227,362
# 98,75598,755
# 62,32462,324
# 107,009107,009
# 45,52045,520
# 142,238142,238
# 218,667218,667
# 124,373124,373
# 75,88175,881
# 150,370150,370
# 47,97647,976
# 71,10871,108
# 110,290110,290
# 41,68641,686
# 30,10530,105
# 173,631173,631
# 37,51737,517
# 22,38622,386
# 29,72429,724
# 32,00632,006
# 30,05530,055
# 40,05040,050
# 38,49238,492
# 48,68048,680
# 37,13637,136
# 32,70032,700
# 35,95635,956
# 35,02035,020
# 39,23739,237
# 39,00239,002
# 23,54923,549
# 41,62141,621
# 40,64540,645

# %%
for i in soup.select('g>g>g'):
    print(i.text)
# Out:
# 고혈압성 질…
# 식도, 위 및 십…
# 당뇨병(E10-E…
# 두드러기 및…
# 급성 상기도…
# 장 감염 질환(…
# 갑상선의 장…
# 대사장애(E7…
# 상기도의 기…
#
#
#
#
# 2019.11
# 2019.12
# 2020.01
# 2020.02
# 2020.03
# 2020.04
# 2020.05
# 2020.06
# 2020.07
# 2020.08
# 2020.09
# 2020.10
# 0
# 200
# 400
# 600
# 800
# 00
# 00
# 00
# 00
# 00
# 00
# 00
# 00
# 00
# 00
# 00
# 00
# 00
# 00
# 00
# 00
# 00
# 00
# 00
# 00
# 00
# 00
# 00
# 00
# 00
# 00
# 00
# 00
# 00
# 00
# 657657
# 657657
# 657657
# 481481
# 481481
# 481481
#
#
#
#
# 강서구
# 금정구
# 기장군
# 남구
# 동구
# 동래구
# 부산진구
# 북구
# 사상구
# 사하구
# 서구
# 수영구
# 연제구
# 영도구
# 중구
# 해운대구
# 0
# 100,000
# 200,000
# 300,000
# 27,36227,362
# 27,36227,362
# 27,36227,362
# 98,75598,755
# 98,75598,755
# 98,75598,755
# 62,32462,324
# 62,32462,324
# 62,32462,324
# 107,009107,009
# 107,009107,009
# 107,009107,009
# 45,52045,520
# 45,52045,520
# 45,52045,520
# 142,238142,238
# 142,238142,238
# 142,238142,238
# 218,667218,667
# 218,667218,667
# 218,667218,667
# 124,373124,373
# 124,373124,373
# 124,373124,373
# 75,88175,881
# ...
