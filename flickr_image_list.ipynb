# %%
from selenium import webdriver
from selenium.webdriver import ChromeOptions
from selenium.webdriver.support.ui import Select
import pandas as pd
import time
import re

options = ChromeOptions()
# options.add_argument('--auto-open-devtools-for-tabs')
options.add_experimental_option("excludeSwitches",["enable-automation"])
options.add_experimental_option("useAutomationExtension","False")
# options.add_argument('headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
options.add_argument('lang=ko_KR')
# options.add_argument("user-agent=Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_5) AppleWebKit 537.36 (KHTML, like Gecko) Chrome")
# options.add_argument("Accept=text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8")

# %%
plant_full_df = pd.read_csv("지리산_처리완료1.csv")
plant_url_df_fin = pd.read_csv("plant_fin_url_210917.csv", encoding='euc-kr')

# %%
plant_full_df.columns
# Out:
# Index(['orplcNm', 'osDstrb', 'peltDesc', 'plantGnrlNm', 'plantPilbkNo',
#        'plantScnmId', 'plantSpecsScnm', 'resultCode', 'resultMsg', 'bfofMthod',
#        'branchDesc', 'brdMthdDesc', 'bugInfo', 'cprtCtnt', 'dstrb', 'engNm',
#        'familyKorNm', 'familyNm', 'farmSpftDesc', 'flwrDesc', 'flwrInfo01',
#        'flwrInfo02', 'flwrInfo03', 'flwrInfo04', 'flwrInfo05', 'flwrInfo06',
#        'flwrInfo07', 'flwrInfo08', 'flwrInfo09', 'fritDesc', 'fritInfo01',
#        'frstRgstnDtm', 'gemmaDesc', 'genusKorNm', 'genusNm', 'grwEvrntDesc',
#        'imgUrl', 'inductionDesc', 'lastUpdtDtm', 'leafDesc', 'leafInfo01',
#        'leafInfo02', 'leafInfo03', 'leafInfo04', 'leafInfo05', 'leafInfo06',
#        'leafInfo07', 'leafInfo08', 'leafInfo09', 'leafInfo10', 'note',
#        'prtcPlnDesc', 'ramentumDesc', 'ramentumInfo01', 'ramentumInfo02',
#        'rootDesc', 'rrngGubun', 'rrngType', 'shpe', 'smlrPlntDesc', 'spft',
# ...

# %%
plant_url_df_fin.columns
# Out:
# Index(['search_nm', 'plant_nm', 'img_nm', 'search_nm2', 'plantGnrlNm',
#        'imgUrl'],
#       dtype='object')

# %%
df_test1 = plant_full_df[~plant_full_df['plantGnrlNm'].isin(plant_url_df_fin['search_nm'])].reset_index(drop=True)[['plantGnrlNm','plantSpecsScnm']]

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import urllib.request
import time
rows=[]
result_num2=[]
result_name2=[]

browser = webdriver.Chrome('C:/chromedriver.exe', options = options)
browser.get("https://www.flickr.com/search/?text=blue%20berry")

# %%
df_test1[:10]
# Out:
#   plantGnrlNm                   plantSpecsScnm
# 0      왕다람쥐꼬리  Lycopodium cryptomerinum Maxim.
# 1      좀다람쥐꼬리             Lycopodium selago L.
# 2          뱀톱       Lycopodium serratum Thunb.
# 3         쇠뜨기             Equisetum arvense L.
# 4          속새             Equisetum hyemale L.
# 5          고비          Osmunda japonica Thunb.
# 6        풀고사리      Gleichenia japonica Spreng.
# 7         네가래          Marsilea quadrifolia L.
# 8        생이가래        Salvinia natans (L.) All.
# 9       물개구리밥   Azolla imbricata (Roxb.) Nakai

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import urllib.request
import time
rows=[]
result_num2=[]
result_name2=[]

browser = webdriver.Chrome('C:/Users/NICE/Downloads/chromedriver_win32/chromedriver.exe', options = options)
browser.get("https://www.flickr.com/search/?text=blue%20berry")

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import urllib.request
import time
result_num3=[]
result_name3=[]
binary = 'C:\chromedriver.exe'
browser = webdriver.Chrome(binary)
browser.get("https://www.flickr.com/search/?text=blue%20berry")
browser.maximize_window()
time.sleep(3)
browser.implicitly_wait(3)
html = browser.page_source
soup = BeautifulSoup(html, "lxml")
for i, y in df_test1[500:].iterrows():
    search=y['plantSpecsScnm']
    browser.find_element_by_xpath('//*[@id="search-field"]').click()
    browser.find_element_by_xpath('//*[@id="search-field"]').clear()
    browser.find_element_by_xpath('//*[@id="search-field"]').send_keys(search)
    browser.find_element_by_class_name('search-icon-button').click()
    time.sleep(2)
#     browser.implicitly_wait(5)
    html = browser.page_source
    soup = BeautifulSoup(html, "lxml")
    
    try:
        if len(soup.find_all('div', {"class" : "view photo-list-view"}))!=0:
            print(i,y['plantGnrlNm'], y['plantSpecsScnm'])
            rows.append({'plantGnrlNm' : "있음"})
        else:
            print('암것도 없네', y['plantGnrlNm'])
            rows.append({'plantGnrlNm' : "없음"})
    except:
        print('-------------------------error----------------------------', y['plantGnrlNm'])
# Out:
# 500 꽃향유 Elsholtzia splendens Nakai
# 암것도 없네 둥근오리방풀
# 암것도 없네 흰오리방풀
# 503 산박하 Isodon inflexus (Thunb.) Kudo
# 암것도 없네 방아풀
# 암것도 없네 자주방아풀
# 506 광대나물 Lamium amplexicaule L.
# 507 익모초 Leonurus japonicus Houtt.
# 암것도 없네 쉽싸리
# 암것도 없네 애기쉽싸리
# 암것도 없네 개쉽싸리
# 암것도 없네 박하
# 암것도 없네 산들깨
# 암것도 없네 들깨풀
# 암것도 없네 들깨
# 암것도 없네 산속단
# 516 배암차즈기 Salvia plebeia R.Br.
# 517 황금 Scutellaria baicalensis Georgi
# 암것도 없네 수골무꽃
# 암것도 없네 애기골무꽃
# 암것도 없네 그늘골무꽃
# 521 좀골무꽃 Scutellaria indica var. parvifolia (Makino) Makino
# 암것도 없네 흰골무꽃
# 523 석잠풀 Stachys japonica Miq.
# 암것도 없네 개석잠풀
# 525 창질경이 Plantago lanceolata L.
# 암것도 없네 왕질경이
# 527 이팝나무 Chionanthus retusus Lindl. & Paxton
# 528 개나리 Forsythia koreana (Rehder) Nakai
# 529 들메나무 Fraxinus mandshurica Rupr.
# 530 광나무 Ligustrum japonicum Thunb.
# 암것도 없네 털개회나무
# 532 들정향나무 Syringa reticulata (Blume) H. Hara
# 암것도 없네 꽃개회나무
# 암것도 없네 털꽃개회나무
# 암것도 없네 앉은좁쌀풀
# 536 외풀 Lindernia crustacea (L.) F.Muell.
# 암것도 없네 논뚝외풀
# 538 주름잎 Mazus pumilus (Burm.f.) Steenis
# ...
